# %% [markdown]
# <a href="https://colab.research.google.com/github/SathwikaKodam/python_fundamentals123/blob/main/pandas_examples_python_libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
# prompt: check for null values in dataframe df, can you also confirm if there are any null values in our dataset

# Check for null values and confirm if there are any in the dataset
null_counts = df.isnull().sum()
has_nulls = null_counts.any()

if has_nulls:
  print("The dataset contains null values.")
  print("Null value counts per column:")
  print(null_counts)
else:
  print("The dataset does not contain any null values.")
# Out:
# The dataset does not contain any null values.
# The dataset does not contain any null values.

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
# prompt: can you find out the mean for salary column

df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
# prompt: can you find out basic stats information on my dataframe df , calculate measurements such as mean , median, mode, variance, std, range , skewness , kurtosis

import pandas as pd

# Assuming your dataframe is named 'df' and has a column named 'salary'

# Calculate mean
mean_salary = df['salary'].mean()

# Calculate median
median_salary = df['salary'].median()

# Calculate mode
mode_salary = df['salary'].mode()[0]  # Access the first mode if multiple exist

# Calculate variance
variance_salary = df['salary'].var()

# Calculate standard deviation
std_salary = df['salary'].std()

# Calculate range
range_salary = df['salary'].max() - df['salary'].min()

# Calculate skewness
skewness_salary = df['salary'].skew()

# Calculate kurtosis
kurtosis_salary = df['salary'].kurt()


print(f"Mean: {mean_salary}")
print(f"Median: {median_salary}")
print(f"Mode: {mode_salary}")
print(f"Variance: {variance_salary}")
print(f"Standard Deviation: {std_salary}")
print(f"Range: {range_salary}")
print(f"Skewness: {skewness_salary}")
print(f"Kurtosis: {kurtosis_salary}")
# Out:
# Mean: 108023.78205128205
# Median: 104671.0
# Mode: 92000
# Variance: 800531254.0427904
# Standard Deviation: 28293.661022264165
# Range: 129160
# Skewness: 0.45210256755588096
# Kurtosis: -0.4017126758820546

# %%
df[df['salary']>50000]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
# prompt: can you filter records where salary is greater than 50000 from my dataframe df

# Filter the DataFrame to include only rows where salary is greater than 50000
filtered_df = df[df['salary'] > 50000]

# Display the filtered DataFrame
filtered_df

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:10,:]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
# prompt: can you select 1st  10 records and all the columns from my dataframe df and show me the output

# Select the first 10 records and all columns
df_first_10 = df.iloc[:10, :]

# Show the output
df_first_10
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-6952212d7b5d> in <cell line: 1>()
# ----> 1 df.mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
# Calculate the mean of only the numeric columns
import numpy as np
df.select_dtypes(include=np.number).mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.groupby('rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
# prompt: can you groupby different categories in my rank column and calculate the mean salary, phd , service values

# Group by 'rank' and calculate the mean of 'salary', 'phd', and 'service'
grouped_data = df.groupby('rank')[['salary', 'phd', 'service']].mean()

grouped_data

# %%
df.groupby('rank')[['salary','service','phd']].mean()
# Out:
#                   salary    service        phd
# rank
# AssocProf   91786.230769  11.307692  15.076923
# AsstProf    81362.789474   2.210526   5.052632
# Prof       123624.804348  21.413043  27.065217

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('Universities.csv')

# %%
plt.hist(df1['SAT'])
plt.xlabel('SAT Scores')
plt.ylabel('Frequency')
plt.title('Distribution of SAT Scores')
plt.show()

# %%
# prompt: can you create a histogram on sat score column in the dataframe df1

plt.hist(df1['SAT'], bins=10)  # You can adjust the number of bins as needed
plt.xlabel('SAT Scores')
plt.ylabel('Frequency')
plt.title('Histogram of SAT Scores')
plt.show()

# %%
sns.histplot(df1['Accept'])
plt.show()

# %%
can you create a histogram on accept column in dataframe df1 using seaborn library
# Out:
#   File "<ipython-input-8-d70c203078a0>", line 1
#     can you create a histogram on accept column in dataframe df1 using seaborn library
#         ^
# SyntaxError: invalid syntax

# %%
can you create a histogram on accept column in dataframe df1 using seaborn library

# %%
# prompt: can you create a histogram on accept column in dataframe df1 using seaborn library

sns.histplot(df1['Accept'])
plt.xlabel('Acceptance Rate')
plt.ylabel('Frequency')
plt.title('Histogram of Acceptance Rate')
plt.show()

# %%
plt.plot(df1['Accept'],df1['SAT'],color='r+')
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Scatter Plot of Accept vs SAT')
plt.show()

# %%
# prompt: can you generate a scatter plot  between accept column and sat column in data frame df1,now can you add red color markers

plt.scatter(df1['Accept'], df1['SAT'], color='red')
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Scatter Plot of Accept vs SAT')
plt.show()

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1.iloc[:,1:3])

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df1['Accept'])
plt.show()

# %%
# prompt: can you create distplot for all the columns in dataframe df1

# Assuming df1 is your DataFrame
for column in df1.columns:
  if pd.api.types.is_numeric_dtype(df1[column]):  # Check if the column contains numeric data
    sns.distplot(df1[column])
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
plt.boxplot(df1['Accept'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79bbf83078e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79bbf8307e20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79bbf8307640>],
#  'medians': [<matplotlib.lines.Line2D at 0x79bbf831c3a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79bbf831c640>],
#  'means': []}

# %%
# prompt: can you create a boxplot on column for dataframe df1

plt.boxplot(df1['Accept'])
plt.xlabel('Acceptance Rate')
plt.ylabel('Values')
plt.title('Boxplot of Acceptance Rate')
plt.show()

# %%
# prompt: can you write a narrative summary on the boxplot of accept column in dataframe df1

The boxplot of the 'Accept' column in the df1 DataFrame provides a visual summary of the distribution of acceptance rates at different universities.

**Key observations from the boxplot:**

* **Median:** The median acceptance rate (represented by the line within the box) shows the central tendency of the data.
* **Interquartile range (IQR):** The box represents the IQR, containing the middle 50% of the acceptance rates.  This suggests the typical range of acceptance rates within the dataset.
* **Outliers:** Any points outside the "whiskers" (the lines extending from the box) are considered potential outliers. These are universities with significantly higher or lower acceptance rates compared to the rest.
* **Skewness:** The boxplot can give a general indication of skewness in the data. If the median is closer to the bottom of the box, it might suggest a right-skewed distribution, implying a larger proportion of universities with lower acceptance rates. Conversely, if the median is closer to the top, it might suggest a left-skewed distribution, implying a larger proportion of universities with higher acceptance rates.

**In essence, the boxplot helps to visualize the overall range of acceptance rates, identify any universities with unusually high or low rates (outliers), and understand the central tendency and spread of the data.**

**Note:** Without actually generating the boxplot, this narrative is a general interpretation based on how boxplots are typically used to summarize data. It would be more accurate to interpret the boxplot based on the generated visual representation.

# %%
import numpy as np

# %%
a = np.array([1,2,3,4])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (4,)

# %%
a.size
# Out:
# 4

# %%
a.sum
# Out:
# <function ndarray.sum>

# %%
a.sum()
# Out:
# 10

# %%
a.prod()
# Out:
# 24

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 4

# %%
b=np.array([(1,2,3,4),(4,5,6,7)])

# %%
b
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (4,)

# %%
b.shape
# Out:
# (2, 4)

# %%
b.size
# Out:
# 8

# %%
b.sum()
# Out:
# 32

# %%
b=b.reshape(4,2)

# %%
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 7]])

# %%
 b[0]
# Out:
# array([1, 2])

# %%
b[0,0]
# Out:
# 1

# %%
b[0,1]
# Out:
# 2

# %%
b[1,0]
# Out:
# 3

# %%
b.sum(axis=0)
# Out:
# array([14, 18])

# %%
b.sum(axis=1)
# Out:
# array([ 3,  7,  9, 13])
